# %% [markdown]
# #  pf_generator
#
# ### Using textgenrnn (and a GPU) to generate text based on scraped poetry.
#
# *Based on work by [Max Woolf](http://minimaxir.com). For more about textgenrnn, you can visit [this GitHub repository](https://github.com/minimaxir/textgenrnn).*
#
# **NOTE: This notebook is meant to be run in Google Colab, for functionality and much faster computation. The first cell, for example, will not run in a Jupyter Notebook.**

# %% [markdown]
# ## Import packages

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ## Upload corpus

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = 'corpus_lined.txt'

# %% [markdown]
# ## Character-based text generator
#
# Set the textgenrnn model configuration here.
#
# (see the [demo notebook](https://github.com/minimaxir/textgenrnn/blob/master/docs/textgenrnn-demo.ipynb) for more information about these parameters)

# %%
model_cfg_linechars = {
    'word_level': False,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 4,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 40,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 100000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg_linechars = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 20,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %%
model_name = 'pf_char_gen_lined'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
# %%time

textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg_linechars['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg_linechars['num_epochs'],
    gen_epochs=train_cfg_linechars['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg_linechars['train_size'],
    dropout=train_cfg_linechars['dropout'],
    validation=train_cfg_linechars['validation'],
    is_csv=train_cfg_linechars['is_csv'],
    rnn_layers=model_cfg_linechars['rnn_layers'],
    rnn_size=model_cfg_linechars['rnn_size'],
    rnn_bidirectional=model_cfg_linechars['rnn_bidirectional'],
    max_length=model_cfg_linechars['max_length'],
    dim_embeddings=100,
    word_level=model_cfg_linechars['word_level'])
# Out:
# Training new model w/ 4-layer, 128-cell LSTMs
# Training on 5,121,185 character sequences.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 5001/5001 [==============================] - 378s 76ms/step - loss: 1.9952
# Epoch 2/20
# 5001/5001 [==============================] - 371s 74ms/step - loss: 1.5777
# Epoch 3/20
# 5001/5001 [==============================] - 367s 73ms/step - loss: 1.5273
# Epoch 4/20
# 5001/5001 [==============================] - 368s 74ms/step - loss: 1.4992
# Epoch 5/20
# 5001/5001 [==============================] - 367s 73ms/step - loss: 1.4795
# ####################
# Temperature: 0.2
# ####################
#  pale stream,
# And the street was the stream of the stream of the sun.
# And the cold candle is closed to the shadow
# of the stone with the statues of the black of the street,
# And she was a bright star that should be some one of the street,
# And the sun was a brown stream,
# And the ship of the street with
#
# wind
# And the stream is free,
# And the world of the wind is bright,
# And the street steam of the street with the stone.
# The street was a man who should have the world with the sun.
# And the world was not the little thing that we seem
# And the little wind is blowing the street
# And the street was the stree
#
#  is bright and strange and shadow
# And the streets of the street of the world.
# The street was a fire and the silence of the street
# And the world is come to the state of the countenance of the world,
# And the world was a street with the stream
# And the street was the stone with the ship
# And the ship of
#
# ####################
# Temperature: 0.5
# ####################
#  eyes
# That see no search and man
# And the wind blind the sun was the state of the street,
# And the sun and the water were still,
# And light their wings and lights and the
# accompanion of the poet in the bath
# of the uncommon good has the night is perhaps
# of the great green streams of the land of the stre
#
#  to the storm
# with a spirit of the stone and the bridge.
# A castle sat in the pillow of the air
# And the slim of drift dips and steam
# Down and strange precious the skies.
# There was nothing more than a fear, the mirror of the sky and the silent heart and cost and forest
# And the gravel stumps and the da
#
# arm window.
# The ships for me in the middle of the feeling of the distance of the water
# And so a secret still because if they still.
# They see the same thing will be seen the reality of the light,
# And the green sands and the mark of this bliss and the mind
# Which would be still and thine day
# And she wa
#
# ####################
# Temperature: 1.0
# ####################
# ch other
# that fording like a sunny bore
# She, which the counter light golden girl gusses, and with great Gather on Mir!
# He cannot came forsake of a clap and colors of place
# two sullites black taining his blood.
# All a tall honey of it
# unto doom, (such poems it were because it seems, we shoulder stalk
#
# ou!
# Monkey, like coral ply, subuat.
# H: Lo, stoodish! Ah, his propertic chaste wealth
# Cursed out the green thin wings between mine;
# And far fame for the pair;
# And the air was given,
# Except, butting with royal syllables' pale,
# To stock the professIon past Annamate—
# Give, brilliant, human vicu by drum,
#
# ues
# Since. I almost just as every arp/
# we aurnal mes
# drummed to the wheel in begin hoora fall.
# The whole angels whose indrept
# is planneled in the hease and wave.
# He shook thee to rove, since with with sun
# Is worked vaunted from interruptive time.
# I never happen, I tremble, and reginnance
# And weep th
#
# Epoch 6/20
# 5001/5001 [==============================] - 359s 72ms/step - loss: 1.4634
# Epoch 7/20
# 5001/5001 [==============================] - 359s 72ms/step - loss: 1.4502
# Epoch 8/20
# 5001/5001 [==============================] - 358s 72ms/step - loss: 1.4384
# Epoch 9/20
# 5001/5001 [==============================] - 360s 72ms/step - loss: 1.4275
# Epoch 10/20
# 5001/5001 [==============================] - 355s 71ms/step - loss: 1.4170
# ####################
# Temperature: 0.2
# ####################
# autiful street
# Where the sun shows and bright and black seasons,
# And the sun shall say, and the moon is still and seen
# The broken shadows of the stage of the sea,
# And the sun shall be the streets of the street
# That the sun showed the waves of the street
# That she saw the sun and the street,
# And the s
#
# of the stars,
# The stars of the steps of the sun,
# And the wind blows on the stars,
# And the stars still the same bright seasons of the sea,
# And the season of the streets of the street,
# And the street of the streets of the sea,
# And the street blows of the street,
# And the sun stands in the street,
# And t
#
#  of the streets of the stage of the waves,
# The light that still have been bred to the same,
# And the stars flowing out of the stars,
# And the sound of the streets of the street
# In the morning wind, the wind is blue
# The street of the shadows of the street,
# And the street of the wind of the stars of the
#
# ####################
# Temperature: 0.5
# ####################
# mmer beaks the sea-call
# the light and the sea we shall watch up the wall,
# The strange face is so clearly in the devil of the sea
# And the reflection of the hands of the colors
# of the stars, the earth that the former stars call
# To the accuration of a holy place to his day.
# The country with the corner
#
# nd past the bloody seasons on the devil of the great street
# By the holes of the moon with my side,
# And the sight of the tree of a dream;
# The sharp waves of the face of the rest of the stars.
# I would find the head of the heart of the light
# Of the hair of the floor of the sea;
# The evening of the broke
#
#  to see
# and all are seventeen.
# The soul is a shawl, that the world is sure,
# And the thing that gives the sound of the wall,
# The priests that glass to summer to the sight of the moon.
# I have melted the world of the world to take it.
# The black board of the stranger, like praise of winter.
# When the sea
#
# ####################
# Temperature: 1.0
# ####################
# l edge,
# Standing along
# The lake that sorrows cent;
# The freshy sending, the age is rough,
# If they was next to the trouser,
# More fair day to wear a mother on thy tides: when vanish'd her
# Midnight bones before her vet:
# But all his tables, John Berrie
# The follietual Ksun, bevala friend,—
# And the perfris
#
# owding if the yelline’s
# coffee covers one nightfall;
# who surf you promise,
# not unmadperable kicks—yet the might seek
# of our abit chanted: our one bloom
# the World?
# Blessing of her
# Which few a symbol of common murdererless suite,
# Nets lined upon my fingers like drains;
# Long there was spent from tale
# E
#
#
# In life to come out of dreary alepiefs and
# as an uneasy-bigger another trail.
# I know my second and no
# The high-blue might breeze locations toiled
# on watching flints
# the go all night among the commotion
# or sound,
# how
# many
# ride dry to sun
# fanelled sentence
# more wrestle
# more earth.
# Took it
# “Finds jamm
#
# Epoch 11/20
# 5001/5001 [==============================] - 350s 70ms/step - loss: 1.4070
# Epoch 12/20
# 5001/5001 [==============================] - 354s 71ms/step - loss: 1.3973
# Epoch 13/20
# 5001/5001 [==============================] - 356s 71ms/step - loss: 1.3879
# Epoch 14/20
# 5001/5001 [==============================] - 353s 71ms/step - loss: 1.3784
# Epoch 15/20
# 5001/5001 [==============================] - 353s 71ms/step - loss: 1.3690
# ####################
# Temperature: 0.2
# ####################
# tars of the stars
# And the sea-walls of the sea,
# And the sound of the stream of the sea,
# And the world is strong, and the sound of the world
# Of the sun and the street of the street,
# And the street winds bright and straight,
# And the stream of the stream of the sea,
# And the stream of the sands of the s
#
#  is like a star
# Of the sea of the stars of the sun,
# And the stream of the threshold of the street
# In the sea of the street, the sun should be
# A shadow of the stars of the sea,
# And the sun should be the soul,
# And the sea was still strange to the street,
# And the stream is strong, and the first world i
#
# ight
# Of the sun and the sun of the sun,
# And the stream of the wind with the streets
# Of the shadows of the street, and the stairs are still.
# The street was the street to the street,
# And the stars were still as the wind is still.
# The stars were still and still,
# And the sea was still and still,
# And the
#
# ####################
# Temperature: 0.5
# ####################
# .
# You see the barren stars,
# The same the streams of the sun,
# And the stream of the shore of the dark,
# And down the stone with the fragrance of the past of the dead.
# A woman will be a fair end
# Who to be stronger than the master, with me and the things
# And love that lies the first thing
# Of hope the li
#
# a mistake.
# But when I had heard the bride-side for the sea,
# While the wind still still dies beside the day
# And so quickly all the past, the moon has still
# The sun we see the scent of the sea,
# And the shadow of the same trees
# Shall see the sun and roads are held and muscles,
# And I will not speak, and
#
# e light,
# And while the silver night rises and broke the dark,
# And the live forms of the past that were the sky
# Where the angels were still all that was great as the roots of light,
# My soul is fled, and then the strange things were
# back to the window, and the transformation of the street
# To the wall
#
# ####################
# Temperature: 1.0
# ####################
# ;
# In knowledge of the hours and date
# Exacting fire the field on the sea.
# At salt streak, whi’res wan to see
# Something, one’s state, could the piping blue collectain years on form,
# and not ever will—slow,
# distilled.
# •
# The corps exist,        washed
# safely first
# loose breast, each clock
# through the l
#
# s of speech
# quietly wonderfully fromber and
# the wild Isranied forms
# beneath the breath,
# Was when I wondered.
# I bluster than a bo-handful of things with me,
# like former nights, meanen
# on oh pallyparl and losat
# Life with Hopkins’ wound’sly
# each of themselves;
# She said, while the angle luts,
# Praise the
#
# e, this is whole
# that we weatched, would withdress
# the rest
# Until they can love all.
# And it is worth too safe to go!
# Let not you.
# Glad be young, when ’tis gone from far-perfect, half warn’t
# sunly echoed
# to escape me around it out? I could not be talking about you and really temperated it—
# scentels e
#
# Epoch 16/20
# 5001/5001 [==============================] - 355s 71ms/step - loss: 1.3595
# Epoch 17/20
# 5001/5001 [==============================] - 357s 71ms/step - loss: 1.3498
# Epoch 18/20
# 5001/5001 [==============================] - 355s 71ms/step - loss: 1.3403
# Epoch 19/20
# 5001/5001 [==============================] - 361s 72ms/step - loss: 1.3307
# Epoch 20/20
# 5001/5001 [==============================] - 359s 72ms/step - loss: 1.3212
# ####################
# Temperature: 0.2
# ####################
# )
# “I will not see the stars of the street of the street,
# And the light of the moon is showering,
# And the wind blows off the street of the street
# Where the stars were still as the sun
# Should be the sound of the stream.
# The street restore the streets of the sea.
# The streets are the same things of the
#
# een
# and the street stars are wonderful
# and the shadow of the streets
# of the streets of the streets
# and the stars of the stones of the street.
# The soul is a strange mother of the street,
# And the sound of the street that lies the sea
# And the shadow of the streets
# Of the streets of the woods and the su
#
# beginning”
# “The words” “the old ones” ““the black and one”
# “The man is a dead” “all the dead” “the day is the same”)
# “The poet is not the soul of the world.”
# And the same thing that lives the season's life
# And the sound of the stream of the street.
# The streets are still and the sea of sunset and the
#
# ####################
# Temperature: 0.5
# ####################
#  window like a beech stroke
# Of money for my father's tears,
# The stars fall down to the grass,
# And shining in the trees, and the solitary arches
# of the springing stars
# where the wind has found a picture of the grass
# And the room the rock that made the stars pass
# Through steam in the sun, and the sun
#
# t of the white corners of my soul,
# The rest of the stars which was the silence the little doctor was the matery of the pale shell.
# The children who march off the sun's sweet,
# And lightly sees the street beneath his head.
# I think away the stars shine,
# Seeing the moon and the shade of a bird,
# Shall fo
#
# nt in a sudden speed.
#
#
#
# THE STARS
#
# Sometimes the earth was wonderful,
# It is the long time we shall not learn
# The sense of the parties which they shall see them around the strings of the poplars
# Over the bridge in the floor.
# The old man will stand to a red lip to the porch in the career and somethin
#
# ####################
# Temperature: 1.0
# ####################
#  clothed roofs:
# The small stars quiet, bright.
# There is a spot of where lay from a worm life
# alone, like a backgood with the wind,
# tuarrarce of the desert girls, a]
# a way
# as to such an archay’s constrainted”
# the inenigua’s dove’s . How can turn with
# wheel? On his
# mouth of their conclusion blindness
#
# te!”
# Then it laved her scarcely wondering,
# And I am she traced
# The timid Day,
# “Or we are here, if you would not preserve all women. Everywhere
# me yet to cold court-broad stone—
# head—yet he sere, Negroes Hantingianly
# Hard seralnes—the spuntoes,
# Where die of all flowering elegants, blown down:
# Of wild
#
# ------------
# In . . o?
# ashimmen.
# Their coat-way breath
# fills gold, here, fire which divines
# twelve-ledges wider are deadly
# only only the act of burdening and funny?
# (He is a life
# Which moves up in the edge of a bugle and
# deliberated hands.
# It’s remembered to marble,
# imagines nearly nothing
# more than
#
# CPU times: user 2h 48min 27s, sys: 14min 17s, total: 3h 2min 45s
# Wall time: 2h 1min 20s

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg_linechars['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg_linechars['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg_linechars['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download(f'{model_name}_weights.hdf5')
files.download(f'{model_name}_vocab.json')
files.download(f'{model_name}_config.json')

# %% [markdown]
# ## Word-based text generator

# %%
model_cfg_linedocs = {
    'word_level': True,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 4,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 10,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 100000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg_linedocs = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 20,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %%
model_name = 'pf_word_gen_lined'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
# %%time

textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg_linedocs['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg_linedocs['num_epochs'],
    gen_epochs=train_cfg_linedocs['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg_linedocs['train_size'],
    dropout=train_cfg_linedocs['dropout'],
    validation=train_cfg_linedocs['validation'],
    is_csv=train_cfg_linedocs['is_csv'],
    rnn_layers=model_cfg_linedocs['rnn_layers'],
    rnn_size=model_cfg_linedocs['rnn_size'],
    rnn_bidirectional=model_cfg_linedocs['rnn_bidirectional'],
    max_length=model_cfg_linedocs['max_length'],
    dim_embeddings=100,
    word_level=model_cfg_linedocs['word_level'])
# Out:
# Training new model w/ 4-layer, 128-cell LSTMs
# Training on 1,296,679 word sequences.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 1266/1266 [==============================] - 114s 90ms/step - loss: 5.1912
# Epoch 2/20
# 1266/1266 [==============================] - 104s 82ms/step - loss: 4.6652
# Epoch 3/20
# 1266/1266 [==============================] - 105s 83ms/step - loss: 4.4328
# Epoch 4/20
# 1266/1266 [==============================] - 105s 83ms/step - loss: 4.2299
# Epoch 5/20
# 1266/1266 [==============================] - 105s 83ms/step - loss: 4.0436
# ####################
# Temperature: 0.2
# ####################
# sea is a tough old man
#
#
#
#  the
#
#  the old woman
#
#  the red - faced
# the red - faced hemlock ,
# and the blue - apple trees
# and the sea - tops ;
# and the sea - star clusters fall ' d ;
# and the dark winds were as the sea - mist
# and the sea - light ,
# and the wind that shines on the wind .
# and the wind is a song of the night ,
# and the stars are still in the sky
# and the sea - light
# that is a fire that is not a sight
# of a light and a groan .
#
#
#
#  the
#
#  i have been
# in the night
# i am the present
# to the last night .
#
#
#
#  the house of the
#
#  the river is a part of the sky ,
# and the of the world ,
# the of the world ,
# the of the world , and the of the world .
#
#
#
#  the
#
#  the old familiar faces
# are the lands
# of the dead ,
# the of their birth
# is not the of the less .
# the very best of the world is still .
#
#
#
#  the
#
#  i have seen the city ,
# the sea - wind blows ,
# the rain is a bough
# where the wind ruffles the trees
# and the wind blows out the wind ;
# and the wind blows out the lights and the night
# the night comes down .
# the wind
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# the of the houses are in the sky .
# the night is a great plain
# and the other words are making
# the lovers are there
# and they are not
# to the same .
# i have seen the city ,
# and the rain is a of the sky .
# and the wind is a flash of the sea .
#
#
#
#  the
#
#  the old man is
# in the night of the night ,
# the night is a day of night ,
# and the snow is still .
#
#
#
#  the
#
#  the sea is a great flood
# and the sea - light is a bough ,
# and a wind blows out the water
# and the rain goes through the wind .
# the wind blows east and the night
# and the night comes down to the sea .
#
#
#
#  the
#
#  the sea is a great man
#
#  the
# of the poor child
#
#  i have seen the singing of the snow ,
# and the night the night ,
# and the day is a day of night ,
# and the day is a day of night ,
# and the light is still , and the light
# is not the stars that fills the storm .
# the storm is the wind - bound ,
# and the is the sun and the sky
# and the light of the sky
#
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# the of the houses are in the sky .
#
#
#
#  the
#
#  the last year is a soldier
#
#  the of the 8 of the river
#
#
#
#  the
#
#  the wind shudders sank down the hill
# the torrent of the sea ,
# and the wind that shines on the blast .
# and the great wind blows coldly ,
# and the rain is a white shadow
# of the night ,
# the of the city , the of the day ,
# the night - star floats ,
# and the wind ruffles the water ,
# and the wind ruffles the leaves ;
# and the wind blows through the trees ,
# and the wind blows east ,
# and the wind blows west ,
# the wind blows coldly ;
# and the wind blows east and the
#
# ####################
# Temperature: 0.5
# ####################
# who is there , ” and i ’ m alive
# we should have been
# to be
# a theory for the world
# and everything is a part of it .
# it is a little smaller ,
# one .
#
#
#
#  the pool of the
#
#  the last scene is a part of the last night
#
#  the man is a man
# who has been taken to the
# of a lost song .
#
#
#
#  the
#
#  we have said
# we are so many kinds of
# of course
# and of this
# a of a century
# and i am waiting for a . . . .
# my mother .
# i have been thinking of the time of the
# we have been believers
# of the of his our friends
# and the two of his children
# though the feet of the whole
# is a mysterious and is not a sign of a
# possibility of the body .
#
#
#
#  the
#
#  i shall have no longer
# what is the gods of the dead ,
# the singing of the night
# the light of a light in the air ,
# and i know not what we know ,
# and i should ask them what i might do .
# but i am so much as i am ,
# and i am waiting for you ,
# i know i am losing the scorn of the dead .
# but i may not be a word
# but a man that was a little property ,
# a - set in the sky ,
# as if i could sing of
#
# ” “ and paris is ruined . ”
# “ i ’ m not a bad woman .
# i dont want to take any door
# to get it down
# and let us say
# that we could tell
# you are the same thing
# to be a woman
# and i am a
# of myself .
# you have seen the
#
#  i am alone
# and i am still .
# i will come to the last night
# and i shall watch the wind
# and the rain and the meadows .
# it was not a place where the moon had been a dream ,
# and he loved me a name to me ,
# and i ' m sure i ' m sure i know .
# i ' ve seen it , i have seen the people
# and rend the water
# and the wind and the sea .
# the land is a mess of itself
# and the of the name of the
# i saw the
# in the rain
# and i am waiting for
# my life
# these are the
# they have no
# longer than
# any of them .
#
#
#
#  the dream
#
#  i have seen the rain
# and the clouds sneer
# and then without
# singular creeps ,
# like a wind ,
# the of the night , and the sun shines on the trees .
#
#
#
#  the
#
#  to the
# of her
# is the
# of the
# i am the
# of the sea .
#
#
#
#  the new year
#
#  this time and the day
# ( there
#
# the while
# in a glass of the
# i hear the - of - the - - -
# sea - wind ,
# and the wind ruffles and leaves and shine ,
# and the wind blows the boughs
# and the wind blows ; the land
# is closed , and the - eyed mariner .
#
#
#
#  the
#
#  the wind shifts
# the wind the drops
# of the gray sea .
#
#
#
#
#
#  all things are
# ‘ and who are
# and i am the last peace
# of a long life , and i had no chance to tell
# of the old man , and he
# is the world of his own love ,
# and he has his own , he has been .
# the young man is a man , and rears an ass
# to the other ' s newspaper ,
# and the wood , and the blue of the rain .
# the night is a great white moon
# in the light of the moon ,
# and the blue twilight ,
# and the wind
# and the red - faced
# the white flower of the sea .
#
#
#
#  lines written in a fog
#
#  the wind moves over the ground
# the old times of the
# old man , who loved his life , whom all his fame
# had been known to the common world .
# the judge of his life , the gift of his
# " and the world ' s are merely the light
# of the world ' s deep core ;
# and the sun - flowers are built ,
#
#
# ####################
# Temperature: 1.0
# ####################
# secret pleasure will heal !
# and i shall cease to the death :
# these are all things as goodly as friend to em ,
# since , and he was not anything but it .
# i cannot the laughing queen
# who stood in waking dreams what i was .
# " behold , by mortals , whom to thee
# new man gaze him in my arms so tones ?
# and that my own hatred had much ,
# how lovely but her nails is a pearl .
# without a lady ’ s dancing , solemn , there wanted two
# to bring something and that i had thought
# attention to desire to love .
# and this morning in this bother me of service
# being in offering for his pains more than half .
# ( and , god within . )
# by the death of the death
# the way which a trampling of a head .
# i am not likely to going around
# but i swear forced into a repair .
# in literary , and on the pavement , his ambition and is atone . these days are with strange lands .
# we ' ve been interesting
# trees , love , and
# words .
# and my fingers troubles my hands
# like a few soft despair on the compassionate trees ?
# she fifteen bore us on the porch :
# and the men of thee then look at ease
# to the changeful shimmering sea ,
# rocking the misers stream of land —
# then as when we sent
# men must go out in the heart ;
# many things the faces of early youth .
#
#
#
# ’ d repeating at others in a countenance ashes .
# feature was this , the mirror standing still ,
# can ’ t inspire it innocent .
# for who next his writer had two .
# according to the foot of his head ,
# in the hospital with burning glory his step ,
# feeling it more than mine .
# and then — long since , herself with whiskey .
# then home we had a little distance ;
# a prompt , but not dead ;
# but in order only to go with savage means to b -
#
#  he is , of what is his mate :
# it will not baseball . thus far into the vacancy that not giving us .
# are you more to admire me , and you those have
# for the heels of your beauty and your mouth will thrust
# your smile to love with you .
# it will never be
# a tie of one passion fixed soft .
# the and the soldier of his house shall disappear in the front of the way
# out of my future course , to your faith
# more than the pipe of laughter , the pleasures point
# — the crowd that will themselves mates ,
# to the bark .
# the festival proclaims it itself in the empty air .
# this is the poem , our delicate day .
# now whispers he leads by muscle or noise
#
#  her mouth must be sad , but wear thine eye ,
# tell to the share of love which parcel the day in pity once —
# i trust the strength of it as i hear
# that never tread
#
# great to my death choose such faith ;
# and canto i first were these , hope , was fleet ;
# on a faithful house of life ;
# did you sunday sunday school .
# but you because i was really a year old back - two -
# - who has to whom the tribes sat down
# nothingness and me again .
# both were there once brought in my nature free .
#
#
#
#  fear , child , early - glass river ,
# field was emblems of shadows by the dome
# of dumb students , for the “ your subject of turned — wait
# touch and father , — to quit thee though i wait
# till i see tell such a word ,
# will the sensations of death may cease .
# flowers with gather lust ;
# and mock them if they call to men
# against your dear life away .
#
#
#
#  dust rose
#
#  the fields are on the ground
# before our day and night are those gates
# of our ages ,
# whose children through frolic there is iron and violent ,
# in the entrance to - day the water
# with blue - wet streak
# poplars in a joyfully
# sharp or greener green paris
# casts out your feet —
# i notice of drift and fence
# that smells the tin , no universe any - cent girl altered away
# this a baby her face for an hair
# on a fortitude as she stood in a wood
# only mount to a
# no day for him ! only the window all
# brings myself the poison down by a
#
#
# Epoch 6/20
# 1266/1266 [==============================] - 105s 83ms/step - loss: 3.8660
# Epoch 7/20
# 1266/1266 [==============================] - 103s 82ms/step - loss: 3.7016
# Epoch 8/20
# 1266/1266 [==============================] - 104s 82ms/step - loss: 3.5482
# Epoch 9/20
# 1266/1266 [==============================] - 103s 82ms/step - loss: 3.4073
# Epoch 10/20
# 1266/1266 [==============================] - 103s 82ms/step - loss: 3.2800
# ####################
# Temperature: 0.2
# ####################
# i am the widow -
#
#  i am the city of the
# i am waiting for the subject of which i
# am i , and the exact
# of my father ’ s face .
# i have seen the parade
# and the ones
# who the railroad took their hands were left ,
# and the faces of the , and the insane
#
#  the people are always rushing and the houses
# and the people who fell
# in the of the world .
#
#
#
#  the garden
#
#  the wind is full of the light
# and the rain falling
# and the ground
# and the evening
# and the
# of the
# i
# the secret of the
# i am waiting
# for the subject
# of
# and
# the
# e is
# when the beloved sire
# and the end of a .
#
#
#
#  the kingdom
#
#  the sun came over the river
#
#  the ground is high , the seaside
# the apple trees are full of the sun .
# i have seen the parade
# i saw a thousand winding sheet
# and the frost grows open and the
# i am the least ten thousand men and women
# and the third .
# i have seen the parade
# i saw a thousand winding sheet
# and the frost grows open and the walls
#
#
#
#  the lonely
#
#  the precise
#
#  i carry it with my glasses .
# i have the ground and music ,
# and the wind and the sky ,
# and the night comes down to the west
# and the gates
#
# i am not afraid
# i am waiting
# for the
# i am waiting
# for the final
# of the
# i am waiting
# for the
# i ’ ve spent my life
# i ’ ll take it out of the corner .
# i am the birds of the deep
# and the noise of the trees
# and the deer are still
# they are no longer any more
# than mine .
# i have seen the parade
# i shall go to the garden - shore ,
# and the night - light of the day
# i could not see the moon
# or the wind of the cloud
# and the sea of the sea .
# i have seen the parade
# i saw a thousand winding sheet
# and the frost grows open and the
# and the sea is a real wind
# and a blue is of the sea .
#
#
#
#  the house of the
#
#  the world is a great and
# the present
# and the flesh of the
# ( with the eyes of the earth and the blast )
# and the earth is a new
#
#  and the sea
# of the sea
#
#
#
#  the moon
#
#  the moon is cold ,
# the yellow - apple is full of the market -
# known before the summer .
# the angels and the men are born
# with the same cry
# of the world where the young men said :
#
#
#
#  the garden
#
#  the wind is full of the leaves .
#
#
#
#  the wreck of the
#
#  the moon is beginning
#
#
#  the
#
#  the sea is full of the dead love
# and the sun is over the blackbird ;
# and the sweet music of the sun
# is as a rose , and the light
# of the sun shone like tides .
#
#
#
#  the
#
#  the moon is full of the dark
#
#
#
#  the wreck of the
#
#  the wind that rises from the reeds
# from the west , and the wind ruffles
# the lilies of the water
# and the wind and the sky
# and the sea - wind
# and the moon
# and the wind
#
#
#
#  the lonely
#
#  the precise
#
#  i ' ve seen the whole of the last night
# and the old man
# with his eyes
# and his hands
# smiled and
# his
# eyes as
# a man can
#
#  his
# is a
# he has
# no
# farther up to his knees .
# he has his money to pay a bitch .
# i think she had a
# and i had done for a beautiful thing .
# i chose the to the line
# and left to get a message .
#
#
#
#  the house of life
#
#  i saw myself
# and i know i ’ m sure i am waiting
# for the most important
# that is the other yours ,
# and the other ,
# the , and the
# of the world .
#
#
#
#  the wreck of the
#
#  the wind is beginning to the night ,
# and the sun is over the sea .
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# s an ' e ' d ' n o ' er ,
# an ' ist o ' a ' a ' a ' ,
# comin ' at its closing time ,
# an ' ' what ' s an ' ' the o ' er the moors ,
# and then the crown ' s nest ,
# and the lively sun and the frost is a breath of noon .
# but when the sun is on the sky
# with a new world
# and my life
# is it a long time .
#
#
#
#  the house of life
#
#  i saw the enormous city
# from the land of the poet ’ s
#
#
#
#  the in the ring
#
#  when i had rooms , and my love ,
# i would not have left me to ,
# but i ' m not a - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# of the pool
#
#  a route of narcissus
# in the valley of the evening ,
# the blazing sun and the sea ,
# the thunders and the sky ,
# the yellow - apple ,
# the snow - white flag over the sky .
# i heard the singing
# of their shining wings ;
# and through the lattice - dumb ,
# and i could hear the smile of my voice ,
# and the pulse of my woman ’ s bliss
# with my own modest pleasures ,
# and scorned , and i ' ll find out the very good
# lord lord , forgive me , forgive me ! i am ,
# in this country room i know ,
# and i have my companions of of my own .
# i will go on
# i ’ m not
# but i can ’ t pay you
# any i ’ ll say .
#
#
#
#  the
#
#  i remember the summer evening
# i wrote my mother ’ s tale
# and my daughter ,
# and all his place is grown , and he is —
# but the help of the snark !
# " o tell me , now i cannot tell ,
# and i have grown so much to me ,
# and i am waiting for a long time
# and how they are .
# and i have seen the names
# and laugh at the rain .
#
#
#
#  the house of the same as poetry is to write now .
# and the poem is turning to the crow :
# the house has left to the dock ;
# she is here ,
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . in the dust . . . i am .
# i am a woman who cries to me
# and my love of my death .
# i know not what i do ,
# and i , from afar ,
# when i was borne and kindled fire ,
# and was ' d the slave ' s , ,
# and turn ' d in the mast and door .
# and then the other , as the sea
# i came into the middle of a corner and a road
# and a silver knob of a rabbit
# and rested . a
# spider - three - , dun fox and gray ;
# but she has no name .
# but when her father died , and she was young , but together
# in the wise thou ' s voice ,
# and turn ' d the ever - selves of the children ,
# the heathen and the giving
# the wisdom of their ancient greece ,
# but the gods of the dead are born .
#
#
#
#  the light
#
#  i ' m going to the hills .
# i am a woman who had come back
#
# ####################
# Temperature: 1.0
# ####################
# )
# — but tried the cause of starlight is no more —
# * by eye and day is seen . travel we opened .
# our god curse
# the world shall fly away
# on eternity ’ s brink ;
# oh , he said , ‘ ‘ the lady , come out , ’ said : “ if even
# a better hell , other ’ s
# quartz , in sight of spring :
# like perfect sheath with the leaves of a glade , giving me the sun . she rose more on the yellow sand
# like prints toward the formless seed .
# this old age has ' d been departing , and so long !
# and each was as a slave unspoken
# kind to creed of but
# venus thinks of like mother - bringing gentleness
# and - string - tones i still will find .
# long ago turned away all night
# and warm swift , to turn them at eve and wit ,
# a or a , sorrows not a come for ,
# but i had the words for thinking ,
# but they
# had no dream . the lake
# perhaps out of the newspaper and almost
# knows what you had a row , it had good too late .
# the thing is cursed with thee . be you rustum ' s son ? i ' ve been your doom .
# ' kept alight fruit - breaking ,
# here truth their food have no edge
# against only the heavy - beating north again .
#
#
#
#  in memoriam a . h . h . obiit mdcccxxxiii :
#
#  long - god dwells broke
#
#
#  most )
# final &
# curled
# before
# & there i dig a eggs
# and a tis to be
# a
# a big wi ’ labouring defy ,
# by bring him wealth to her town
# from a fort quiet wood ?
# for i had no skill to paint ,
# and my great plain within my keys
# into that shift ocean into the wreck of thought
# the shadow of the forest green tree ,
# seems that any space which had spoken as best
# or an old feeling .
# i wanted to walk
# in the surf — on something was the billow ;
# longing for beauty , where — and onward crush that half - falling leaf ?
#
#
#
#  writ in a street station
#
#  all night the
# was black that night
# the marks of the moon and stars lends ; and mine
# are dusky and ;
# fill up the keys
# and elanor ' s plague on the account ;
# and ye of living how once in these doth the noise , i
# to be my gaze ,
# i in the branches wet banks of power ; i
# tastes as i , in the sitting on your head .
# adieu the they ’ pour o ’ er apples phrase .
# o ’ er my pale limbs have never been ours
# ‘ now walk on an egg station ,
# in the vast boards standing on ,
# turn and go , and turn the bright homes the muse should find
# and even the worth
# of shared but just to before the gods of ours ,
# but while
#
# bit upon , as dropped the breeze
# sheds dark and saw him not ; but see her sigh
# tongues with necks and boys under wiry in rushing mass water
# red with women
# and over it
# the
# as the camp
# never so
# that the river - heaps of a great green peak , of pale foot ,
# or shimmer of thunder ,
# slowly crossed , thru the passengers ’ a winter .
# the scratching she questioned ,
# how they lay upon me where a man stood up ,
# but what birth was
# thou my home , i shall be still ; each grain
# shall walk through the water - stanzas in the morning , following
# the fleet “ lamps are transfigured ” : but call and asked by
# the other
# warblers - apart
# into a wooden house .
# america lived here in the corner , in the bleak houses on the street
# west pavement
# is nothing less
# to keep a speech over my side for this is a tiger ,
# but the art is harmless ,
# and the stranger shall pray .
#
#
#
#  to the songs
#
#  i cannot do
# now i want
# mother .
# when you think , that
# to me , be
# your dark last baby ' life .
# thou ' s face to the world of delight .
# " what is the name ? — " hast heard ? "
# yea , i will cheek so far without imagination ;
# say i won ’ t forget the future leave
# a brightness . when you called talk , i ’
#
# Epoch 11/20
# 1266/1266 [==============================] - 104s 82ms/step - loss: 3.1558
# Epoch 12/20
# 1266/1266 [==============================] - 104s 82ms/step - loss: 3.0485
# Epoch 13/20
# 1266/1266 [==============================] - 104s 82ms/step - loss: 2.9409
# Epoch 14/20
# 1266/1266 [==============================] - 106s 84ms/step - loss: 2.8406
# Epoch 15/20
# 1266/1266 [==============================] - 105s 83ms/step - loss: 2.7433
# ####################
# Temperature: 0.2
# ####################
# the lit
# of the red
# and the contours of my heart
# and my heart ’ s
# my body
# i was
# my mother
# and my father died
# and i had given me a bit .
# i ' m a boy ,
# a dime ,
# comin thro ' the rye ,
# gin a body kiss a body , need a body cry
# to the cool - press of his eye ,
# the of the 30 message ,
# the prophet without a different
# and the of others .
# i think i was somewhere or a man
# that was a man
# in a hole .
# i was a widow
# in the night
# but it is a deep core
# to make the world
# to which else
# the imagination
# that is the only thing
# that is not
# the
# of this world
# that is
# the
# of the
# experience of the
# and the living
# .
# i am among the hills
# and the great city lost
# and the unhappy little children
# and the other faces of their children
# in the forest , and their hands are out .
# the blood of the world is in the young .
#
#
#
#  the eyelids
#
#  the wind rests for you
# and you want to turn your money in the sun
# you can ’ t leave me
# to the left you ’ ve lost
# in the end of the night .
#
#
#
#  the law : “ come , you ' re going to do not them .
# but when the
#
# tired of the fields of the dust .
# i have seen the old man who is coming to -
# the people of the world .
# the cold music of the tide
# the cold , the water ,
# the seaweed from the marble ,
# the low and the bold sir bedivere :
# " the bride was often as one royal bird alone ,
# one side , the thorn - thorn apples ,
# one , and the huge , the pool , the
# young boy , the girl ,
# the thing she had played with her face ;
# she was ready to know ,
# and she was a man .
# i could not have a son
# or j .
# he would have a boy .
# i helped to be in this room .
# i see the white moon ,
# the singing , the little , the storm , the winds ,
# the enormous wave of the far horizon
# and the wild wheel of the tiny nameless
# the pleasures mocking its cup
# and the blue - of bleeding feet
#
#
#
#  the tide of the orchard
#
#  the wind blows east , the wind blows west ,
# the moon shines like a mist
# and turning , and now i am laid out ,
# and the eyes are fed with eyes .
#
#
#
#  the
#
#  i ' m going down , you ' re -
# time . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . .
#
# clothes , ears ,
# shelter , haste
# over the roots of the sun ,
# and the colors of the loves are the
# of the dead , the deep joy ,
# the twilight , the stars , the flowers , the birds ,
# and the birds are grey ,
# and the wind stalks shine on the stream
# and the bridge of a city
# between the
# ocean
# the world is easily bound to the sky .
# the perfumed cloths shall be absent .
# the light is a glass ,
# the wind is a rose , a golden shaft
# among the ,
# the rain - birds , the flowers of the tree ,
# the chorus .
# i am the woman who cries in the
# stray lies in the great hall ,
# and garden - like pigs ,
# the six nails into a row of silver ,
#
#
#
#  the smell of the dead
#
#  i am putting my life into a great concern
# with a look of things .
#
#
#
#  the
#
#  i ' m going to you
# i ' m still in the garden
# where i am a shit .
# i want to go to my store
# and i am waiting
# for a
# social recognition
# poem
# must be
# a
# to grow .
#
#
#
#  the last of the
#
#  the last century was a post .
# i didn ’ t think .
# i guess , i think i ’ m going to begin
# to the dogs .
# when the dog comes back , the table is
#
# ####################
# Temperature: 0.5
# ####################
# /
# oxus blazed wit coffee coffee / er her laundry / have
# no water / you gonna marry me
# / you got up / / wit you / cause
# to trouble & / i didn ’ t get to
# have i wanted to say .
# i see
# you were sitting down
# and wondering about you .
# i could almost tell you .
# i tell you so .
#
#
#
#  a singing ladder
#
#  the wind shakes the garden paths ,
# the stars sparkle beneath the sea ;
# and the sky was a noble voice ,
# and a land was a - set in the corn .
# it was the west , and the stars seem to sweep
# the moon , and the night , the tide ,
# the moonlight in the moon ,
# and the blue of reeds
# flung the drink
# of the wore skull ,
# the fingers ,
# the warm her breasts of her own bosom quick ,
# her cheeks grow on her tender how ,
# and thus the spit of the
# and the window - cars ,
# the berries and the horns of the open - shod sun .
# the day in june , the wind blows east ,
# the above the sky - drops of the cloud
# and the sea - wind , the waves
# that , like a chance , i found it ,
# i had my right .
#
#
#
#  the
#
#  i ' m going down to a ' i '
# an ' i ' m " an ' " an ' s any says
# '
#
# for their country ,
# to the native music of
# the land where the fickle
# is good to inarticulate .
# the curse of the metal
# of the centuries .
#
#
#
#  the mrs ’
#
#  the is rides the man and the children
# who have not the of art .
#
#
#
#  the young bride
#
#  i ’ m a
# i ’ ve in the house with my belly
# i am i
# am not a bad woman ’ s flesh
# and i ’ m hanging on the ground in the street
# will go to sleep .
#
#
#
#
#
#  the night comes up
#
#  the wind blows east
# and the clouds go by the wind ,
# and the sea swings in the forest .
#
#
#
#  the presence
#
#  i think i am
# i ’ m
# waiting
#
#  and the light
# that reminds me me a song
# of which i was so sure as a fire
# of my own flesh , a of my own
# self knowing it is the same .
# it is a time to be seen
# and then the great door was covered with a shell .
# he had the only one
# who were waiting
# to a certain
# a friend
# of the future
# that is a part of it ,
# the of the living soul , in its true
# of life , and to the north , and the power ,
# the man of the age .
#
#
#
#  the
#
#  the war comes up
# from the river
# i
#
# had
# a little girl , and threw it
# at the labor , and the waiting
# for eight o ’ clock ,
# when it was so far flown ,
# and the was the passionate sorrow of the world ,
# and the silence of the earth a halo round me .
#
#
#
#  the urn of
#
#  i walked in , the of the town
# and the workmen of the dead .
# i would have a friend
# who could see that i could not not be afraid again
# i have nothing to do what i have to do
# and i am not going to
# nothing but the only one
# can ’ t get a
# pattern on the president ’ s
# taking his back to the cliff for his
# great price and isolt
# of poverty . from the wood
# that speaks to the act of
# the more than that .
# vi
# to conquer ‘ even as if
# to - morrow ’ s grace
# to hear the honour ’ s prayer .
# the hills are not yet known before
# they were a young kid
# because they must be lonely
# i can ’ t .
#
#
#
#  the thorn tree
#
#  i am a
# they watched the place
# i am climbing the street - bed
# in a summer ’ s sleeping perfume ,
# the moon and tears
# kept for the warm wind , and on the trees
# to the cold crest of the water
# which is a leafy dome ,
# and a mountain - bough ,
# and the broad stream was still curved
#
# ####################
# Temperature: 1.0
# ####################
# ’ in that cold ! )
# that ’ s not our life , returned - risen , dutch with the flowers , and the drive ,
# and the big stand in sleepless a lamp , which turns from
# a of air and water and deeper darkness flee away from afar
# the colors of the night ;
# one is a lovely sight ,
# but then slips on spot of definite —
# believing he said to alice —
# quick no bitterness into the ve !
# your bark , i do not know an echo of airs ?
# or sublime with one soul to remember a year ;
# ’ s mute ! the , the knife ,
# over sudden may , thro ’ ’ the boogie - swung waters
# do i once the door in my vision might mean
# in the mountains . , over the steps
# you could not look in grain , or coach , .
# but with the , in the base of leaves going .
# then when the moon swallow ' d from the wall ;
# although ' twas the force of god , which
# might mean , a , the time , for my struggle lies .
# already i love thee , give me thee .
# o thou of death ! o days and gentle ,
# thou hast thou direction ' d in hidden valley of christ ?
# he called the house by the ;
# and , for his i shall be thee
# and when wert thou islands — oh ! death —
# if you will never learn
# my vision like a kiss and the sky ,
# my own you
#
# sings .
# and now it lasting out again
# my heart is with what is now it is of the time . you are to say we are ready in the stairs - air ,
#
#  green , glowing from sea - fears bowery
# in song , and night long , and sleep with me ,
# i fear the music of their sights ,
# nor may by resistance ,
# not to higher the blood
# of time , its own , its fully , bands
# ,
# the simple direct - wiser
# be bad
# for the impossible absurd !
# his eyes are rust and cannot be ;
# nor child of freight as is war !
# a pleasant sets in ,
# and rebirth of gold honey as a tired
# with its wings on neck , to the snakes .
# honour of women there is sweetest flowers —
# " the boy , who " how such as here , so fair ;
# " a touching of heaven like another face ,
# comes , and herself awoke as he entered .
# around the room all singing
# here weaves upon
# day , there even the ease of brilliant ’ shines
# face i think that tired walls draw all my dear —
# stay ’ d in all the toiling all with them
# thief ! not
# the heart , though the word may fail ,
# all real ,
# all the living into !
# thine eyes of sorrow , and guard thee loud ,
# till thou art dead , they say not made !
# but what lies , as fire makes hoary ,
# a happier than
#
# as strangers gazing on the bosom of the cliffs of a mountain works
# the sea , because go beyond ,
# a touch of the boredom , a flowering bark over a glass and one might have
# ashes of light .
#
#
#
#  the second year
#
#  an miracle . the new made good fortune to have hours with and new
# the best of the summer - time .
# johnson
#
#
#
#  the rose . the more finally of the subway station
# ’ s best to work .
# then their highest , is rare , are now
# the men of the blind men ,
# whare the age that slain sugar grown ,
# and wherefore ? the shady mists are moving
# with hate ; and watch the star .
# here beneath them melts , caressed
# by the a pond that she flew .
# and at the top that gorgeous where the sun is real .
#
#
#
#  the dry
#
#  awhile my flower is blue ,
# spills through my face and drops
# of the green isles of father his age wither , and the towns ,
# sinking , lo , the sun , the sight ,
# let none go further .
#
#
#
#  self portrait
#
#  down a new enemy .
# among these april fool , — thus ,
# and what is life ! "
# half - said . " — it is very mine ! "
# but clif had been caring , — and what i knew since it died ,
# my heart did fourteen years ago ,
# “ the nature for other hopes
# and
#
# Epoch 16/20
# 1266/1266 [==============================] - 105s 83ms/step - loss: 2.6549
# Epoch 17/20
# 1266/1266 [==============================] - 106s 84ms/step - loss: 2.5682
# Epoch 18/20
# 1266/1266 [==============================] - 106s 84ms/step - loss: 2.4882
# Epoch 19/20
# 1266/1266 [==============================] - 106s 84ms/step - loss: 2.4113
# Epoch 20/20
# 1266/1266 [==============================] - 108s 85ms/step - loss: 2.3396
# ####################
# Temperature: 0.2
# ####################
# ,
# but the of a : the very lovely flower
# of the melody
# of the earth
# and the of the cities
# of the dead world .
#
#
#
#  the pilgrim
#
#  the white day of the sun - people lit by the sun
# and the sea - wind ,
# the seed of the oar - possessed dance ,
# the rocks , the twain , the smell of death ,
# the color that is certain that i should not have
# to know the way to be
# in the dark , the slow
# of the trembling .
# the rain is here tonight ,
# the room where there is nothing here in
# the lights of the street .
# the black rain comes from the road .
# the sun is turning ,
# the shadows are yellow ;
# and the wind blows east and the night
# through the valley ,
# oh , i do not know .
#
#
#
#  the
#
#  the moon is full of the forward ,
# the moon has got away
# and there are birds
# in the mid - night ,
# the priests , and the men ' s sorrow ,
# the of the sons of grace
# has its dwelling on the way ,
# and the rage of the of smiles ,
# and the wild violets and the dews ,
# and the sky of the skies ,
# and the night is dark with the cold winds
# that sing the night ’ s tale .
# and the air is not so white .
# you are a great dream , and a tale ,
#
# the big bear - eye - anxious
# with the dark and lonely head
# and the sunshine of the sun .
# the words seem to learn ,
# the things of the smile ,
# the of the of them ,
# the hope of beauty , the song
# of the beautiful , the greek , the sword - worn hold
# of his thin white horse ’ s wings ,
# and his face was white , and he sank
# in his arms . he speaks : the angel is a thrush
# the white flower that wears a :
# it is like a sky .
# it is not in the silence of the night ,
# the scent of the gray star
# into the wide water
# and the sea
# i am
# on the floor
# and the light
# will never get a
# even though it is to be a place of beauty .
#
#
#
#  the
#
#  o love , i am all that i am not .
# i am not much
# i know not what i
# am i ,
# i know not what can i do ,
# what if i do ,
# i know that the world is past ,
# and the world of those who are fed with music ,
# and beauty and death will not make sense ;
# and , if he sees that spot ,
# but with the happy heart of mortal men ,
# and the old time of a palace wrought ,
# and to the hour of old friends ,
# and the wild longing —
# and the old , the brown ,
# the
#
# am angry with you .
#
#
#
#  in the air of
#
#  i saw the yellow and the sky
# and narrow in the water .
#
#
#
#  the seen rain
#
#  the wind blows over the lakes and the wave
# is dark and out of the light ,
# the moving of the dead ,
# the moon - voices of the bells that are singing
# and falling asleep under the sky .
#
#
#
#  the
#
#  i ' m going to you
# i ' m still as i was
# when i was a child
# and a girl of ice ,
# and he doesn ’ t move
# his own kind , he knows
# he was unhappy to the day .
# he was too late ,
# and i cried
# and never was my father , and if i could
# not
# but never quite
# as if
# ever i had
# and i had
# no longer
# but
# it is not so
# that is a part of life .
#
#
#
#  the
#
#  the trees are full of ice
# and there are three clouds and low
# and nothing but a handful of the sky
# into the shower of the sea .
# the moon in the iam
# of the first grey eye
# and the
# of the moon
# i am the
# when i am the first
# i am the
# of the harlem
#
#
#
#
#
#  i have to
# you are the poem i wrote
# poetry .
# i have read from the
# i saw the city in
#
# ####################
# Temperature: 0.5
# ####################
# . . . . . . . . killed by the
# and in the will . i ’ m going on tomorrow , but i ’ m
# not much .
#
#
#
#
#
#  these are the roses that are wet
# as your branches gleam .
#
#
#
#  the poem of poetry
#
#  i know what i ’ m doing in
# i am a
# for my father will never need of you .
# i am not much too much ;
# and i have seen the way
# and saw an arm ' s voice :
# the broad - blossom round his brown gate ,
# when the sad rich oak - shiver ' d flag
# right in their black beat , and turning the milk .
# “ why will bloom a night , ”
# and she said — ‘ but i ’ m sorry , say ,
# and i ’ ve never known a friend
# like a child who has lost his life
# a slips of tall and two
# and a palace of pearl & who
# the angels with the souls who shot him out of the arrow ,
# and wondered looked at the corners ;
# the house and business and therefore suffering
# and the life they are not to the gods .
#
#
#
#
#
#  o hymen king ,
# what is thy been ? why should i know
# thine ? i am a friend ,
# but a world - house will lov ’ d ;
# the soul , the fear that clings
# the of the sea , the strong gleam of heaven
# is pure of thine
#
# the great birds go round .
# and the young girl of the children and the children in the universe
# of grass , the
# and the eyes of the world
# and the old gods of the life that build the sky .
#
#
#
#  the city
#
#  the red star
# of the ah america
# you are the color of your bed
# i excuse you love you
# and if you can ’ t die you got
# for a , i ’ m not here or you .
#
#
#
#  the slept
#
#  o beautiful , o small swallow ,
# a o ' er the flow ' s laughing eye !
# and , in a , of the ,
# the quail ,
# the watch , the of the mind ,
# the world is as a cat - star can be sweet ,
# and it takes a soul to its mark ,
# and that it is a voice that is going
# to see the trees ,
# and the wind and plain .
# the lady there is a word for the man who
# has a wave to his trousers ,
# and his brain was just as chance .
# a gentle fully is — promise !
# how long , in sunlight and time ,
# the shield of a long - day ' s roar ,
# and , tranquil , winding , at the edge of the ocean .
# the of the valley was a piece of parallel
# and it is as if it is not going to me .
#
#
#
#  to my boy
#
#  once i was a and
#
# .
# love is west . . . . . . . . . wheels .
# . . . . . . . . . .
# . . . . . . . . . . .
# it was hell - year .
# and i told him , “ i ’ m not a bit .
# i know not what i see ,
# what was i i ?
# when i was old ,
# i had ,
# and stood a very long - dug through the boat
# and the snows are black ,
# and the clouds are , the storms of the hush
# were hidden by the process the voice of the
# was breaking out together
# in the secret
# of the forest
# the same year
# of bright
# speed
#
#
#
#  song
#
#  the poet must be done instead
# and the word living .
#
#
#
#  the year - days
#
#  i was a little man , and a didst for his part ,
# if i could have ' d needs no more
# than i , and my king is dead ;
# i will not live in the cool thine that which i
# may fade while still we wander but as the sea —
# we are the joy of our dreaming back .
# but in the sky
# the little sound of the evening
# the curse of the law .
# i have looked upon the bed ,
# and i could hear a cry , and a waking may - church ,
# drag down the ground .
# the nerves with gold looks like bread ,
# the
#
# ####################
# Temperature: 1.0
# ####################
# blood for a book . there was
# no man nor the moon
# has come to me .
#
#
#
#  so great , i am wont to say ;
# my army can flee his holy !
# marriage beside ! — and for thy red confusion
# comes to thee for thee , praised her birth !
# yet ! for a mortal love song .
# look on ! but ah ! the commands —
# you had locked in a delightful sun
# that somewhere along the horizon i sang death ,
# and from it to myself a song
# play south to read weed to drink
# ing her till she got crazy
# to go to on the next .
# my father
# happy to listen into the silence of the white .
# it is writ a cough and there it :
# i cannot go , and mindful , clasped his blowing nose , and feel
# the merry rocks over ripple and the sands
# of lakes and cuts
# with sounds accursed glee ; yea ,
# strong o ' er me ! will i grow at the flowers ?
# thus could not not let him come when forty .
# st . michael was busy , and pressed it from the under stone
# where the beaten rock came ,
# the knock - horse it lay , and out
# the rocks , all the clock nightly .
# practical legs that night .
# two towards five a way go
# and a catch ,
# down the streets like the sun ,
# and you will drink my fellow - ’ s .
# see , open sun , dangerous stars
#
# virtue , without and not , –
# it is queen , with a boy or any bar or a home , but the nice god
# wants to believe in prayer .
# let us return so green the of the blaze
# and like a fire , not born .
# now , never , though neither man nor ever nor nor
# nor , in the matter that ceased . i and searching if ever
#
#  meant a .
# _ _ _ _ _ is wondering what it is
# there is what you can , and just for poetry ,
# is coming from the and in the ii ,
# and the children of long time ,
# like a music , a tale ; a oneself to me
# springing from my doomed . someone
# somewhere
# i hear from
# into him
# and i put him to the steel honey , which she is — or of her singing feelings ; she lie
# when her body shook upon a hill
# already , and she said .
# but with good myth , the gentle , true .
# i ’ ve happy then absurd this
# to go back without name
# matthew who everywhere
# have
# the time of we being
# one
#
#
# the goddess singular
#
#  the love of the light that hath itself alone .
# the bitter limbs of fever - twisting sleep and more worth ,
# and stumps best like lips to say ,
# my lord have gate for life in partial ,
# and lower ages vain in hand , though my arms
# keep on mine , the hurt his soul ;
#
#
#
#  scene now
# for a day is beginning
# the one must be made . history is growing longer
# than yesterday between us some of girls have been
# used to be said , then we told a little while
# should the sweat off grow straight old to the sight ?
# one thing —
# that thin , off blue , the classic , pale sky .
# a painted stone was gone .
# the week ,
# every wood opened the to the waters ,
# brothers ,
# they have seen daisies in our world ,
# a new
# on other .
# four day day
# ( the poor dream would be heard ’ painted reaches ,
# as if they could not gather the ground
# which had pressure , of rain and through ground ;
# spreading tears and blowing caverns and wings
# as as a song unto us understand
# when she looks out i can see her . just as thine
# the pale feet stir in silence : sweet again ,
# my fancy ! the challenge of men they wave
# the bloom of bells with stone .
# “ i cannot wood your
# because i should love you if they did . they ’ ve never sun
# death , lying right out in a time ’ s sound .
#
#
#
#  : one day
#
#  wearing a crest of leaves and let its willow blooms know ;
# there , ah heaven , and earth shall not be with alike ,
# thou , that it wink with dust .
# the wild flowers above ,
# i caught upon a new
# day , and ruin the
#
# CPU times: user 47min 58s, sys: 2min 54s, total: 50min 53s
# Wall time: 36min 4s

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg_linedocs['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg_linedocs['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg_linedocs['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = f'{model_name}_gentext_{timestring}.txt'

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download(f'{model_name}_weights.hdf5')
files.download(f'{model_name}_vocab.json'))
files.download(f'{model_name}_config.json')

# %% [markdown]
# # Etcetera
#
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)
#
# Note:
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.
